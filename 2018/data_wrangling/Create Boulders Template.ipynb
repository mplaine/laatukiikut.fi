# %% [markdown]
# # Suomen Parhaat Boulderit 2018: Create Boulders Template
# March 17, 2018

# %% [markdown]
# <br>
# Load the datafile `survey_-_cleaned.csv`, which contains the form responses to the **Suomen Parhaat Boulderit 2018** survey.

# %%
import pandas as pd
import numpy as np


# Load cleaned dataset
spb2018_df = pd.read_csv("data/survey_-_cleaned.csv")

# Drop duplicates (exclude the Timestamp column from comparisons)
spb2018_df = spb2018_df.drop_duplicates(subset=spb2018_df.columns.values.tolist()[1:])
spb2018_df.head()
# Out:
#              Timestamp Suostumus      Ikä Sukupuoli  Pituus (cm)  \
# 0  12/17/2017 18:36:32     Kyllä  35 - 39      Mies          184
# 1  12/17/2017 18:48:44     Kyllä  30 - 34      Mies          180
# 2  12/17/2017 18:49:04     Kyllä  30 - 34      Mies          180
# 3  12/17/2017 18:53:03     Kyllä  25 - 29      Mies          190
# 4  12/17/2017 19:10:14     Kyllä  25 - 29      Mies          180
#
#   Vaikein *ulkona* kiipeämäsi boulder             Boulderin nimi  \
# 0                                 7A+                 Muistipeli
# 1                                  7B                     Voodoo
# 2                                  8A                   One love
# 3                                  7A  Bitch slap and male pinch
# 4                                  8A                  Maitomies
#
#   Olen lähettänyt (kiivennyt) kyseisen boulderin  \
# 0                                          Kyllä
# 1                                          Kyllä
# 2                                          Kyllä
# 3                                          Kyllä
# 4                                          Kyllä
#
#   Kuvaile boulderia kolmella (3) adjektiivilla  \
# 0            erilainen, kolmiulotteinen, pitkä
# 1                       Tiukka, kaunis, hänkki
# 2                            Dynaaminen,Herkkä
# 3                 kuumottava, miehekäs, korkea
# 4                    Herkkä, vaikea, klassikko
#
#    Kuvaile boulderia omin sanoin (vapaaehtoinen)  \
# 0                                            NaN
# 1  Siihen löyty aivan helevetin nätti sekvenssi.
# 2          Linjan esteettisyys ja monipuolisuus.
# 3                                            NaN
# 4                                            NaN
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                             Boulderin pääotetyypit.1  \
# 0                                                NaN
# 1                                                NaN
# 2  Krimppi (crimp), Slouppi (sloper), Reuna/kantt...
# 3                  Krimppi (crimp), Slouppi (sloper)
# 4                                   Slouppi (sloper)
#
#        Boulderin kiipeämiseen vaadittavat pääkyvyt.1 Lisää suosikkiboulder #3  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2  Keskivartalo (core), Huukkaus (hook), Kompress...                    Kyllä
# 3  Huukkaus (hook), Psyykkinen vahvuus  (mental s...                    Kyllä
# 4  Huukkaus (hook), Kompressio (compression), Sor...                       Ei
#
#   Boulderin nimi.2 Olen lähettänyt (kiivennyt) kyseisen boulderin.2  \
# 0              NaN                                              NaN
# 1              NaN                                              NaN
# 2  Kun Jari koskee                                            Kyllä
# 3          Kaljala                                            Kyllä
# 4              NaN                                              NaN
#
#   Kuvaile boulderia kolmella (3) adjektiivilla.2  \
# 0                                            NaN
# 1                                            NaN
# 2                          halattava,komea,ylpeä
# 3                         Hankki, terävä, karhea
# 4                                            NaN
#
#   Kuvaile boulderia omin sanoin (vapaaehtoinen).2  \
# 0                                             NaN
# 1                                             NaN
# 2                         Kivenlaatu kuin fontsu.
# 3                                             NaN
# 4                                             NaN
#
#           Boulderin pääprofiilit.2  \
# 0                              NaN
# 1                              NaN
# 2     Pysty (wall), Kantti (arête)
# 3  Pysty (wall), Hänkki (overhang)
# 4                              NaN
#
#                             Boulderin pääotetyypit.2  \
# 0                                                NaN
# 1                                                NaN
# 2        Slouppi (sloper), Reuna/kantti (edge/ledge)
# 3  Kahva (jug), Slouppi (sloper), Reuna/kantti (e...
# 4                                                NaN
#
#        Boulderin kiipeämiseen vaadittavat pääkyvyt.2
# 0                                                NaN
# 1                                                NaN
# 2  Keskivartalo (core), Huukkaus (hook), Kompress...
# 3        Dyno (dyno), Huukkaus (hook), Voima (power)
# 4                                                NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# <br>
# Create boulders template file `boulders_-_template.csv`.

# %%
def create_boulders_template():
    boulder_name_columns = [spb2018_df["Boulderin nimi"], spb2018_df["Boulderin nimi.1"], spb2018_df["Boulderin nimi.2"]]
    unique_boulder_names_s = pd.concat(boulder_name_columns, ignore_index=True).dropna().drop_duplicates().sort_values().reset_index(drop=True)
    unique_boulder_names_s.to_csv("data/boulders_-_template.csv", index=False)
    
create_boulders_template()
